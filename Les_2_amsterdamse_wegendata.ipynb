# %% [markdown]
# <a href="https://colab.research.google.com/github/SebastiaanBekker/practical_python_101/blob/master/Les_2_amsterdamse_wegendata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

url = "https://api.data.amsterdam.nl/bereikbaarheid/v1/road-sections/load-unload/"

response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)
else:
    print("Request failed with status code:", response.status_code)
# Out:
# FeatureCollection

# %%
for _, row in df.iterrows():
  print(row[0]['geometry']['coordinates'][0][0])
  break
# coordinates = (row[0]['geometry']['coordinates'][0][0])
# Out:
# [4.824583055581009, 52.390146916631636]

# %%
print(df.iloc[1]['features']['properties']['street_name'])
# Out:
# Terheideweg

# %%
import folium

# Create a folium map centered at a specific location
map_center = [52.3702, 4.8952]  # Amsterdam coordinates
zoom_level = 12
map_amsterdam = folium.Map(location=map_center, zoom_start=zoom_level)

# Iterate over the rows in the DataFrame
for _, row in df.iterrows():
    # Extract the coordinates from the JSON data
    coordinates = (row[0]['geometry']['coordinates'][0][0])
    straatnaam = (row['features']['properties']['street_name'])
    print(straatnaam)

    # Convert coordinate pairs to string values
    coordinate_pairs = []
    for coord in coordinates:
      coordinate_pairs.append(str(coord))
    reversed_coordinate_pair = coordinate_pairs[::-1]
    
    # Create a folium PolyLine object using the coordinates
    marker = folium.Marker(location=reversed_coordinate_pair, icon=folium.Icon(color='green', tooltip=straatnaam))
   
    # Add the PolyLine to the map
    marker.add_to(map_amsterdam)

# Display the map
map_amsterdam
# Out:
# Rhôneweg
# Terheideweg
# Hoofddorpweg
# Mercatorplein
# Zeilstraat
# Hudsonhof
# Kinkerstraat
# Kinkerstraat
# Kinkerstraat
# Prinses Irenestraat
# Kinkerstraat
# Van Reigersbergenstraat
# Leidseplein
# Leidseplein
# Leidsekruisstraat
# Leidsekruisstraat
# Lange Leidsedwarsstraat
# Korte Leidsedwarsstraat
# Zieseniskade
# Zieseniskade
# Leidseplein
# Runstraat
# Leidsegracht
# Korte Leidsedwarsstraat
# Huidenstraat
# Wijde Heisteeg
# Hartenstraat
# Berenstraat
# Raadhuisstraat
# Raadhuisstraat
# Haarlemmerplein
# 1e van der Helststraat
# Albert Cuypstraat
# Ferdinand Bolstraat
# Ferdinand Bolstraat
# Ferdinand Bolstraat
# Ferdinand Bolstraat
# Ferdinand Bolstraat
# Frans Halsstraat
# Ferdinand Bolstraat
# Albert Cuypstraat
# Ferdinand Bolstraat
# Ferdinand Bolstraat
# Heiligeweg
# Heiligeweg
# Spui
# Singel
# Singel
# Reguliersdwarsstraat
# Kalverstraat
# Kalverstraat
# Kalverstraat
# Kalverstraat
# Oudezijds Achterburgwal
# Oudezijds Achterburgwal
# Heiligeweg
# Muntplein
# Singel
# Rokin
# Langebrugsteeg
# Reguliersdwarsstraat
# Muntplein
# Rokin
# Nieuwendijk
# Nes
# Nes
# Nes
# Kalverstraat
# Kalverstraat
# Kalverstraat
# Kalverstraat
# Gravenstraat
 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_628547b8a3b1e9390191cf649fd0d7d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_628547b8a3b1e9390191cf649fd0d7d4 = L.map(
#                 &quot;map_628547b8a3b1e9390191cf649fd0d7d4&quot;,
#                 {
#                     center: [52.3702, 4.8952],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db939606175cada9e927ff776256368e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_628547b8a3b1e9390191cf649fd0d7d4);
#
#
#             var marker_fe65158a7eb1544e2080b0c70b9c7d7a = L.marker(
#                 [52.390146916631636, 4.824583055581009],
#                 {}
#             ).addTo(map_628547b8a3b1e9390191cf649fd0d7d4);
#
#
#             var icon_9f1e6c06b5d0fd7381038eb11a5cb2e6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;tooltip&quot;: &quot;Rh\u00f4neweg&quot;}
#             );
#             marker_fe65158a7eb1544e2080b0c70b9c7d7a.setIcon(icon_9f1e6c06b5d0fd7381038eb11a5cb2e6);
#
#
#             var marker_fce3b591c2fff33df002004e638e2f05 = L.marker(
#                 [52.35260458877681, 4.840788092782371],
#                 {}
#             ).addTo(map_628547b8a3b1e9390191cf649fd0d7d4);
#
#
#             var icon_d3e7534817f352ad616233bfa5074350 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;tooltip&quot;: &quot;Terheideweg&quot;}
#             );
#             marker_fce3b591c2fff33df002004e638e2f05.setIcon(icon_d3e7534817f352ad616233bfa5074350);
#
#
#             var marker_cb3ef063bbbfb6e5bc5754e3c4ff9057 = L.marker(
#                 [52.35099845836898, 4.851947488454083],
#                 {}
#             ).addTo(map_628547b8a3b1e9390191cf649fd0d7d4);
#
#
#             var icon_645bf036714087874715a276eb8412ec = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;tooltip&quot;: &quot;Hoofddorpweg&quot;}
#             );
#             marker_cb3ef063bbbfb6e5bc5754e3c4ff9057.setIcon(icon_645bf036714087874715a276eb8412ec);
#
#
#             var marker_d368e1d7f0692aa59286da4415592c4c = L.marker(
#                 [52.36921431716953, 4.851495639656814],
#                 {}
#             ).addTo(map_628547b8a3b1e9390191cf649fd0d7d4);
#
#
#             var icon_201868d5f845c10d03d04b51c6ebab66 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;tooltip&quot;: &quot;Mercatorplein&quot;}
#             );
#             marker_d368e1d7f0692aa59286da4415592c4c.setIcon(icon_201868d5f845c10d03d04b51c6ebab66);
#
#
#             var marker_774a1ac177bc1191de7a940091ae13ea = L.marker(
#                 [52.3508047993602, 4.8535334754478],
#                 {}
#             ).addTo(map_628547b8a3b1e9390191cf649fd0d7d4);
#
#
#             var icon_5cd6de8565feb1fc35c0e46d84e097dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;tooltip&quot;: &quot;Zeilstraat&quot;}
#             );
#             marker_774a1ac177bc1191de7a940091ae13ea.setIcon(icon_5cd6de8565feb1fc35c0e46d84e097dc);
#
#
#             var marker_326af5a90f17f0058ae963be012c22fd = L.marker(
#                 [52.370341517519, 4.85201052550229],
#                 {}
#             ).addTo(map_628547b8a3b1e9390191cf649fd0d7d4);
#
#
#             var icon_918ef126d24b263527c6175068aaea71 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;, &quot;tooltip&quo
